# %% [markdown]
# #### Задача 1 (5 баллов).
#
# Напишите класс для обработки файла conllu syntagrus_tiny.conllu. У класса должен быть главный метод "считать конлу" и дополнительные методы для подсчета. Неплохо также написать отдельный класс Token для токенов - каждое слово или знак пунктуации в формате описывается 10 значениями, разделенными знаком табуляции, подробнее можно почитать [тут](https://universaldependencies.org/format.html).

# %% [markdown]
# В файле syntagrus_tiny.conllu (на самом деле это обычный текстовый файл, который можно открыть любым текстовым редактором) содержится морфосинтаксическая разметка в формате UD. В этом файле содержится три размеченных предложения. Каждое предложение имеет свой ID (# sent_id = ), исходный текст (# text = ) и собственно пословную разметку. Один из методов вашего класса должен уметь читать информацию из файла таким образом, чтобы в атрибутах класса хранился список объектов класса Sentence; в классе Sentence, в свою очередь, должен храниться список объектов класса Token, а класс Token должен хранить в атрибутах 10 значений ячеек формата conllu.
#
# Второй метод должен подсчитывать, какие части речи и в каком количестве количестве встречаются в наших трех предложениях. Вывод должен выглядеть примерно так:
#
#     POS       %
#     NOUN   15.2
#
# (Проценты можно посчитать, поделив на общее число слов, ну и не забудьте про красивый вывод с помощью f-строк).
#
# Третий метод должен отсеять все знаки пунктуации с помощью тегов (обратите внимание на их часть речи) и посчитать количество уникальных слов в наших трех предложениях.
#
# Наконец, четвертый метод должен посчитать количество слов, которые по форме совпадают со своей леммой.
#
# Внешними библиотеками пользоваться пока нельзя.
#
# Чтобы загрузить файл на колаб, можно воспользоваться командой wget:

# %%
# !wget https://raw.githubusercontent.com/rsuh-python/bac21-25/main/term06/01-Exercise/syntagrus_tiny.conllu

# %%
# your code here

# %% [markdown]
# #### Задача 2 (5 баллов).
#
# Хотим написать программу - базу данных для библиотеки. Нам понадобится класс "книга", который будет содержать автора, название, жанр и количество страниц; а также класс "библиотека", в котором в атрибутах будут сидеть все наши книги. В библиотеку будут поступать запросы: нужно будет выдавать перечень всех книг одного автора, перечень всех книг конкретного жанра, а также проверять, что книга такого автора и с таким названием есть (вам хорошо помогут генераторные выражения для всех этих вещей, а еще можно переопределить магический метод \_\_eq\_\_ у класса "книга" - он должен возвращать bool, а внутри него можно сравнивать атрибуты экземпляров self и other - и проверять наличие объекта класса "книга" в списке).

# %%
# your code here
